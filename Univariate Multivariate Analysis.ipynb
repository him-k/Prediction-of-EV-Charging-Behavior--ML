# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Himani\\Desktop\\pp/data.csv')

# %%
df.head()
# Out:
#                          id  clusterId              Date connectionTime  \
# 0  5bc90cb9f9af8b0d7fe77cd2         39  Wed, 25 Apr 2018      11:08:04
# 1  5bc90cb9f9af8b0d7fe77cd3         39  Wed, 25 Apr 2018       13:45:10
# 2  5bc90cb9f9af8b0d7fe77cd4         39  Wed, 25 Apr 2018      13:45:50
# 3  5bc90cb9f9af8b0d7fe77cd5         39  Wed, 25 Apr 2018      14:37:06
# 4  5bc90cb9f9af8b0d7fe77cd6         39  Wed, 25 Apr 2018      14:40:34
#
#   disconnectTime Time Diff  Total Hours               donechargingTime  \
# 0   13:20:10 GMT  02:12:06         2.20  Wed, 25 Apr 2018 13:21:10 GMT
# 1   00:56:16 GMT  11:11:06        11.19  Wed, 25 Apr 2018 16:44:15 GMT
# 2   23:04:45 GMT  10:19:45        10.33  Wed, 25 Apr 2018 14:51:44 GMT
# 3   23:55:34 GMT  09:18:28         9.31  Wed, 25 Apr 2018 16:05:22 GMT
# 4   23:03:12 GMT  08:22:38         8.38  Wed, 25 Apr 2018 17:40:30 GMT
#
#    kWhDelivered                               sessionId  ...  Precip Type  \
# ...

# %% [markdown]
# # Categorical Data

# %%
#No categorical data

# %% [markdown]
# # Numercal Data

# %% [markdown]
# #Session length

# %%
#Histogram
import matplotlib.pyplot as plt
plt.hist(df['Total Hours'],bins=20)
# Out:
# (array([24., 29., 34., 26., 26., 15., 17., 13., 26., 41., 20.,  9.,  3.,
#          5.,  6.,  0.,  2.,  2.,  0.,  1.]),
#  array([ 0.1   ,  1.0035,  1.907 ,  2.8105,  3.714 ,  4.6175,  5.521 ,
#          6.4245,  7.328 ,  8.2315,  9.135 , 10.0385, 10.942 , 11.8455,
#         12.749 , 13.6525, 14.556 , 15.4595, 16.363 , 17.2665, 18.17  ]),
#  <BarContainer object of 20 artists>)

# %%
#DistPlot
sns.distplot(df['Total Hours'])
# Out:
# C:\Users\Himani\AppData\Local\Temp\ipykernel_15316\2942018623.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total Hours'])
# <Axes: xlabel='Total Hours', ylabel='Density'>

# %%
#Boxplot
sns.boxplot(df['Total Hours'])
# Out:
# <Axes: >

# %% [markdown]
# #Energy consumption

# %%
#Histogram
import matplotlib.pyplot as plt
plt.hist(df['kWhDelivered'],bins=20)
# Out:
# (array([66., 47., 51., 26., 30., 44.,  9.,  7.,  4.,  1.,  3.,  3.,  1.,
#          2.,  0.,  0.,  2.,  2.,  0.,  1.]),
#  array([ 0.546 ,  2.9091,  5.2722,  7.6353,  9.9984, 12.3615, 14.7246,
#         17.0877, 19.4508, 21.8139, 24.177 , 26.5401, 28.9032, 31.2663,
#         33.6294, 35.9925, 38.3556, 40.7187, 43.0818, 45.4449, 47.808 ]),
#  <BarContainer object of 20 artists>)

# %%
#DistPlot
sns.distplot(df['Total Hours'])
# Out:
# C:\Users\Himani\AppData\Local\Temp\ipykernel_15316\2942018623.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total Hours'])
# <Axes: xlabel='Total Hours', ylabel='Density'>

# %%
#Boxplot
sns.boxplot(df['kWhDelivered'])
# Out:
# <Axes: >
