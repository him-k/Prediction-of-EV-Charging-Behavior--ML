# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.ensemble import StackingRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVR
from xgboost import XGBRegressor
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
# loading the csv data to a Pandas DataFrame
ev= pd.read_csv('C:\\Users\\Dell\\Desktop\\pp/bigg.csv')

# %%
# checking the number of missing values
ev.isnull().sum()
# Out:
# id                          0
# clusterId                   0
# connectionTime              0
# Num.Rep.                    0
# disconnectTime              0
# donechargingTime            1
# SessionLength               0
# Avg.Sess.                   0
# kWhDelivered                0
# Avg.Cons.                   0
# sessionId                   0
# siteId                      0
# spaceID                     0
# stationID                   0
# timezone                    0
# userID                   1199
# userInput                1199
# Precip Type                 0
# temperature                 0
# Avg. Humidity               0
# Avg Wind Speed(mph)         0
# Wind Bearing(degrees)       0
# Visibility(km)              0
# Loud Cover                  0
# Pressure(millibar)          0
# Battery_Pack Kwh            0
# FastCharge_KmH              0
# dtype: int64

# %%
ev["donechargingTime"] = ev["donechargingTime"].fillna(ev["donechargingTime"].mode()[0])

# %%
NAs = pd.concat([ev.isnull().sum()], axis=1, keys=["EV"])
NAs[NAs.sum(axis=1) > 0]
# Out:
#              EV
# userID     1199
# userInput  1199

# %%
ev.pop("userID")
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1194   NaN
# 1195   NaN
# 1196   NaN
# 1197   NaN
# 1198   NaN
# Name: userID, Length: 1199, dtype: float64

# %%
ev.pop("userInput")
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 1194   NaN
# 1195   NaN
# 1196   NaN
# 1197   NaN
# 1198   NaN
# Name: userInput, Length: 1199, dtype: float64

# %%
ev.drop(['id','clusterId','connectionTime','sessionId','spaceID','stationID','disconnectTime','siteId','donechargingTime','timezone','Precip Type','Loud Cover'],axis=1,inplace=True)

# %%
ev.corr()
# Out:
#                        Num.Rep.  SessionLength  Avg.Sess.  kWhDelivered
# Num.Rep.               1.000000      -0.071010  -0.107489     -0.130661  \
# SessionLength         -0.071010       1.000000   0.380336      0.349359
# Avg.Sess.             -0.107489       0.380336   1.000000      0.227223
# kWhDelivered          -0.130661       0.349359   0.227223      1.000000
# Avg.Cons.             -0.040154       0.288598   0.773066      0.231452
# temperature           -0.005883      -0.315319  -0.835803     -0.262378
# Avg. Humidity          0.000890      -0.303165  -0.863568     -0.233600
# Avg Wind Speed(mph)    0.082359      -0.081812  -0.266609     -0.025725
# Wind Bearing(degrees) -0.102735       0.114141   0.276224     -0.099936
# Visibility(km)        -0.177679       0.003940  -0.143602      0.078063
# Pressure(millibar)    -0.118644       0.259002   0.485590      0.249317
# Battery_Pack Kwh       0.020703      -0.054652  -0.081316     -0.026580
# FastCharge_KmH         0.008337      -0.079983  -0.156699     -0.006242
#
#                        Avg.Cons.  temperature  Avg. Humidity
# Num.Rep.               -0.040154    -0.005883       0.000890  \
# SessionLength           0.288598    -0.315319      -0.303165
# Avg.Sess.               0.773066    -0.835803      -0.863568
# kWhDelivered            0.231452    -0.262378      -0.233600
# Avg.Cons.               1.000000    -0.698765      -0.849067
# temperature            -0.698765     1.000000       0.850414
# Avg. Humidity          -0.849067     0.850414       1.000000
# Avg Wind Speed(mph)    -0.548857     0.100510       0.396623
# Wind Bearing(degrees)   0.087399    -0.046195      -0.181635
# Visibility(km)         -0.116635     0.259534       0.109862
# Pressure(millibar)      0.415482    -0.574374      -0.507359
# Battery_Pack Kwh       -0.032511     0.031727       0.019863
# FastCharge_KmH         -0.099096     0.119235       0.127938
#
#                        Avg Wind Speed(mph)  Wind Bearing(degrees)
# Num.Rep.                          0.082359              -0.102735  \
# SessionLength                    -0.081812               0.114141
# Avg.Sess.                        -0.266609               0.276224
# kWhDelivered                     -0.025725              -0.099936
# Avg.Cons.                        -0.548857               0.087399
# temperature                       0.100510              -0.046195
# Avg. Humidity                     0.396623              -0.181635
# Avg Wind Speed(mph)               1.000000              -0.256970
# Wind Bearing(degrees)            -0.256970               1.000000
# Visibility(km)                   -0.121604              -0.049020
# Pressure(millibar)               -0.133499              -0.112676
# Battery_Pack Kwh                  0.018198              -0.056938
# FastCharge_KmH                    0.020462              -0.071260
#
#                        Visibility(km)  Pressure(millibar)  Battery_Pack Kwh
# Num.Rep.                    -0.177679           -0.118644          0.020703  \
# SessionLength                0.003940            0.259002         -0.054652
# Avg.Sess.                   -0.143602            0.485590         -0.081316
# kWhDelivered                 0.078063            0.249317         -0.026580
# Avg.Cons.                   -0.116635            0.415482         -0.032511
# temperature                  0.259534           -0.574374          0.031727
# Avg. Humidity                0.109862           -0.507359          0.019863
# Avg Wind Speed(mph)         -0.121604           -0.133499          0.018198
# Wind Bearing(degrees)       -0.049020           -0.112676         -0.056938
# Visibility(km)               1.000000            0.210063          0.057092
# Pressure(millibar)           0.210063            1.000000         -0.014193
# Battery_Pack Kwh             0.057092           -0.014193          1.000000
# FastCharge_KmH               0.043039           -0.024295          0.105323
#
#                        FastCharge_KmH
# Num.Rep.                     0.008337
# SessionLength               -0.079983
# Avg.Sess.                   -0.156699
# kWhDelivered                -0.006242
# Avg.Cons.                   -0.099096
# temperature                  0.119235
# Avg. Humidity                0.127938
# Avg Wind Speed(mph)          0.020462
# Wind Bearing(degrees)       -0.071260
# Visibility(km)               0.043039
# Pressure(millibar)          -0.024295
# Battery_Pack Kwh             0.105323
# FastCharge_KmH               1.000000

# %%
ev.describe()
# Out:
#           Num.Rep.  SessionLength    Avg.Sess.  kWhDelivered    Avg.Cons.
# count  1199.000000    1199.000000  1199.000000   1199.000000  1199.000000  \
# mean     14.840467       3.546372     2.895396      6.443036     5.465263
# std       4.004081       2.867130     0.223573      4.871629     0.605820
# min       0.040000       0.010000     2.410000      0.000000     3.620000
# 25%      12.000000       2.130000     2.750000      3.700000     4.920000
# 50%      16.000000       3.010000     2.830000      5.790000     5.590000
# 75%      17.000000       3.965000     2.930000      6.975000     5.810000
# max      23.900000      55.240000     3.550000     47.810000     6.450000
#
#        temperature  Avg. Humidity  Avg Wind Speed(mph)  Wind Bearing(degrees)
# count  1199.000000    1199.000000          1199.000000            1199.000000  \
# mean     30.840901      39.845421            12.729166             188.645538
# std       3.311170       3.334805             1.836852              98.281920
# min      24.370000      33.840000            10.240000              10.000000
# 25%      28.510000      37.565000            11.040000             120.000000
# 50%      31.660000      39.380000            12.490000             195.000000
# 75%      33.550000      42.950000            14.780000             271.000000
# max      35.980000      45.100000            15.640000             339.000000
#
#        Visibility(km)  Pressure(millibar)  Battery_Pack Kwh  FastCharge_KmH
# count     1199.000000         1199.000000       1199.000000     1199.000000
# mean        14.790342         1007.787873         78.156797      584.951626
# std          2.129531            3.449437         30.711861      233.955636
# min          9.900000         1003.100000         16.700000        0.000000
# 25%         14.170000         1005.180000         54.000000      380.000000
# 50%         15.730000         1006.920000         78.000000      594.000000
# 75%         16.100000         1008.450000        100.000000      788.000000
# max         17.300000         1016.850000        206.000000      999.000000

# %%
ev.corr()
# Out:
#                        Num.Rep.  SessionLength  Avg.Sess.  kWhDelivered
# Num.Rep.               1.000000      -0.071010  -0.107489     -0.130661  \
# SessionLength         -0.071010       1.000000   0.380336      0.349359
# Avg.Sess.             -0.107489       0.380336   1.000000      0.227223
# kWhDelivered          -0.130661       0.349359   0.227223      1.000000
# Avg.Cons.             -0.040154       0.288598   0.773066      0.231452
# temperature           -0.005883      -0.315319  -0.835803     -0.262378
# Avg. Humidity          0.000890      -0.303165  -0.863568     -0.233600
# Avg Wind Speed(mph)    0.082359      -0.081812  -0.266609     -0.025725
# Wind Bearing(degrees) -0.102735       0.114141   0.276224     -0.099936
# Visibility(km)        -0.177679       0.003940  -0.143602      0.078063
# Pressure(millibar)    -0.118644       0.259002   0.485590      0.249317
# Battery_Pack Kwh       0.020703      -0.054652  -0.081316     -0.026580
# FastCharge_KmH         0.008337      -0.079983  -0.156699     -0.006242
#
#                        Avg.Cons.  temperature  Avg. Humidity
# Num.Rep.               -0.040154    -0.005883       0.000890  \
# SessionLength           0.288598    -0.315319      -0.303165
# Avg.Sess.               0.773066    -0.835803      -0.863568
# kWhDelivered            0.231452    -0.262378      -0.233600
# Avg.Cons.               1.000000    -0.698765      -0.849067
# temperature            -0.698765     1.000000       0.850414
# Avg. Humidity          -0.849067     0.850414       1.000000
# Avg Wind Speed(mph)    -0.548857     0.100510       0.396623
# Wind Bearing(degrees)   0.087399    -0.046195      -0.181635
# Visibility(km)         -0.116635     0.259534       0.109862
# Pressure(millibar)      0.415482    -0.574374      -0.507359
# Battery_Pack Kwh       -0.032511     0.031727       0.019863
# FastCharge_KmH         -0.099096     0.119235       0.127938
#
#                        Avg Wind Speed(mph)  Wind Bearing(degrees)
# Num.Rep.                          0.082359              -0.102735  \
# SessionLength                    -0.081812               0.114141
# Avg.Sess.                        -0.266609               0.276224
# kWhDelivered                     -0.025725              -0.099936
# Avg.Cons.                        -0.548857               0.087399
# temperature                       0.100510              -0.046195
# Avg. Humidity                     0.396623              -0.181635
# Avg Wind Speed(mph)               1.000000              -0.256970
# Wind Bearing(degrees)            -0.256970               1.000000
# Visibility(km)                   -0.121604              -0.049020
# Pressure(millibar)               -0.133499              -0.112676
# Battery_Pack Kwh                  0.018198              -0.056938
# FastCharge_KmH                    0.020462              -0.071260
#
#                        Visibility(km)  Pressure(millibar)  Battery_Pack Kwh
# Num.Rep.                    -0.177679           -0.118644          0.020703  \
# SessionLength                0.003940            0.259002         -0.054652
# Avg.Sess.                   -0.143602            0.485590         -0.081316
# kWhDelivered                 0.078063            0.249317         -0.026580
# Avg.Cons.                   -0.116635            0.415482         -0.032511
# temperature                  0.259534           -0.574374          0.031727
# Avg. Humidity                0.109862           -0.507359          0.019863
# Avg Wind Speed(mph)         -0.121604           -0.133499          0.018198
# Wind Bearing(degrees)       -0.049020           -0.112676         -0.056938
# Visibility(km)               1.000000            0.210063          0.057092
# Pressure(millibar)           0.210063            1.000000         -0.014193
# Battery_Pack Kwh             0.057092           -0.014193          1.000000
# FastCharge_KmH               0.043039           -0.024295          0.105323
#
#                        FastCharge_KmH
# Num.Rep.                     0.008337
# SessionLength               -0.079983
# Avg.Sess.                   -0.156699
# kWhDelivered                -0.006242
# Avg.Cons.                   -0.099096
# temperature                  0.119235
# Avg. Humidity                0.127938
# Avg Wind Speed(mph)          0.020462
# Wind Bearing(degrees)       -0.071260
# Visibility(km)               0.043039
# Pressure(millibar)          -0.024295
# Battery_Pack Kwh             0.105323
# FastCharge_KmH               1.000000

# %%
sns.distplot(ev['kWhDelivered'],color='pink')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9088\3648164053.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ev['kWhDelivered'],color='pink')
# <Axes: xlabel='kWhDelivered', ylabel='Density'>

# %%
correlation = ev.corr()
print(correlation['kWhDelivered'])
# Out:
# Num.Rep.                -0.130661
# SessionLength            0.349359
# Avg.Sess.                0.227223
# kWhDelivered             1.000000
# Avg.Cons.                0.231452
# temperature             -0.262378
# Avg. Humidity           -0.233600
# Avg Wind Speed(mph)     -0.025725
# Wind Bearing(degrees)   -0.099936
# Visibility(km)           0.078063
# Pressure(millibar)       0.249317
# Battery_Pack Kwh        -0.026580
# FastCharge_KmH          -0.006242
# Name: kWhDelivered, dtype: float64

# %%
ev
# Out:
#       Num.Rep.  SessionLength  Avg.Sess.  kWhDelivered  Avg.Cons.
# 0        11.13           2.20       3.55          7.93       6.44  \
# 1        13.75          11.19       3.55         10.01       6.44
# 2        13.76          10.33       3.54          5.26       6.44
# 3        14.62           9.31       3.55          5.18       6.44
# 4        14.68           8.38       3.55         10.12       6.44
# ...        ...            ...        ...           ...        ...
# 1194     16.00           3.22       2.57          1.82       3.62
# 1195     19.00           1.51       2.41          4.73       4.07
# 1196     12.00           3.28       2.70          3.69       3.85
# 1197     13.00           1.89       2.42          3.82       3.93
# 1198     12.00           2.95       2.95          4.03       4.03
#
#       temperature  Avg. Humidity  Avg Wind Speed(mph)  Wind Bearing(degrees)
# 0           24.37          34.85                13.54                    300  \
# 1           24.37          34.85                13.54                    300
# 2           24.37          34.85                13.54                    300
# 3           24.37          34.85                13.54                    300
# 4           24.37          34.85                13.54                    300
# ...           ...            ...                  ...                    ...
# 1194        35.98          40.55                10.35                    305
# 1195        35.98          40.55                10.35                    305
# 1196        35.98          40.55                10.35                    305
# 1197        35.98          40.55                10.35                    305
# 1198        35.98          40.55                10.35                    305
#
#       Visibility(km)  Pressure(millibar)  Battery_Pack Kwh  FastCharge_KmH
# 0                9.9             1004.55              70.0             940
# 1                9.9             1004.55              45.0             250
# 2                9.9             1004.55              75.0             620
# 3                9.9             1004.55              74.0             560
# 4                9.9             1004.55              28.5             190
# ...              ...                 ...               ...             ...
# 1194            16.1             1005.18              45.0             260
# 1195            16.1             1005.18              65.0             345
# 1196            17.3             1005.18             118.0             670
# 1197            17.3             1005.18              28.0             215
# 1198            17.3             1005.18              70.0             800
#
# [1199 rows x 13 columns]

# %%
#Boxplot
sns.boxplot(ev['kWhDelivered'])
# Out:
# <Axes: >

# %%
model=IsolationForest(n_estimators=500,max_samples='auto',contamination=0.04,max_features=1.0)
model.fit(ev[['kWhDelivered']])
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.04, n_estimators=500)

# %%
ev['newkWh']=model.decision_function(ev[['kWhDelivered']])
ev['anomaly']=model.predict(ev[['kWhDelivered']])
ev.head(10)
# Out:
#    Num.Rep.  SessionLength  Avg.Sess.  kWhDelivered  Avg.Cons.  temperature
# 0     11.13           2.20       3.55          7.93       6.44        24.37  \
# 1     13.75          11.19       3.55         10.01       6.44        24.37
# 2     13.76          10.33       3.54          5.26       6.44        24.37
# 3     14.62           9.31       3.55          5.18       6.44        24.37
# 4     14.68           8.38       3.55         10.12       6.44        24.37
# 5     14.73          10.56       3.54          7.91       6.44        24.37
# 6     14.80           3.67       3.54         15.29       6.44        24.37
# 7     14.97           4.13       3.53          6.95       6.43        24.37
# 8     15.18           3.08       3.53          2.17       6.43        24.37
# 9     15.20           3.29       3.52          2.44       6.43        24.37
#
#    Avg. Humidity  Avg Wind Speed(mph)  Wind Bearing(degrees)  Visibility(km)
# 0          34.85                13.54                    300             9.9  \
# 1          34.85                13.54                    300             9.9
# 2          34.85                13.54                    300             9.9
# 3          34.85                13.54                    300             9.9
# 4          34.85                13.54                    300             9.9
# 5          34.85                13.54                    300             9.9
# 6          34.85                13.54                    300             9.9
# 7          34.85                13.54                    300             9.9
# 8          34.85                13.54                    300             9.9
# 9          34.85                13.54                    300             9.9
#
#    Pressure(millibar)  Battery_Pack Kwh  FastCharge_KmH    newkWh  anomaly
# 0             1004.55              70.0             940  0.131611        1
# 1             1004.55              45.0             250  0.078603        1
# 2             1004.55              75.0             620  0.187820        1
# 3             1004.55              74.0             560  0.187508        1
# 4             1004.55              28.5             190  0.076597        1
# 5             1004.55             110.0             620  0.134037        1
# 6             1004.55              35.8             220  0.036680        1
# 7             1004.55              45.0             420  0.208240        1
# 8             1004.55              50.0             650  0.127309        1
# 9             1004.55              77.0             540  0.137625        1

# %%
outliers_counter = len(ev[ev['anomaly'] == -1])
outliers_counter
# Out:
# 48

# %%
ev_data = ev[(ev['kWhDelivered'] <=17)]

# %%
ev_data
# Out:
#       Num.Rep.  SessionLength  Avg.Sess.  kWhDelivered  Avg.Cons.
# 0        11.13           2.20       3.55          7.93       6.44  \
# 1        13.75          11.19       3.55         10.01       6.44
# 2        13.76          10.33       3.54          5.26       6.44
# 3        14.62           9.31       3.55          5.18       6.44
# 4        14.68           8.38       3.55         10.12       6.44
# ...        ...            ...        ...           ...        ...
# 1194     16.00           3.22       2.57          1.82       3.62
# 1195     19.00           1.51       2.41          4.73       4.07
# 1196     12.00           3.28       2.70          3.69       3.85
# 1197     13.00           1.89       2.42          3.82       3.93
# 1198     12.00           2.95       2.95          4.03       4.03
#
#       temperature  Avg. Humidity  Avg Wind Speed(mph)  Wind Bearing(degrees)
# 0           24.37          34.85                13.54                    300  \
# 1           24.37          34.85                13.54                    300
# 2           24.37          34.85                13.54                    300
# 3           24.37          34.85                13.54                    300
# 4           24.37          34.85                13.54                    300
# ...           ...            ...                  ...                    ...
# 1194        35.98          40.55                10.35                    305
# 1195        35.98          40.55                10.35                    305
# 1196        35.98          40.55                10.35                    305
# 1197        35.98          40.55                10.35                    305
# 1198        35.98          40.55                10.35                    305
#
#       Visibility(km)  Pressure(millibar)  Battery_Pack Kwh  FastCharge_KmH
# 0                9.9             1004.55              70.0             940  \
# 1                9.9             1004.55              45.0             250
# 2                9.9             1004.55              75.0             620
# 3                9.9             1004.55              74.0             560
# 4                9.9             1004.55              28.5             190
# ...              ...                 ...               ...             ...
# 1194            16.1             1005.18              45.0             260
# 1195            16.1             1005.18              65.0             345
# 1196            17.3             1005.18             118.0             670
# 1197            17.3             1005.18              28.0             215
# 1198            17.3             1005.18              70.0             800
#
#         newkWh  anomaly
# 0     0.131611        1
# 1     0.078603        1
# 2     0.187820        1
# 3     0.187508        1
# 4     0.076597        1
# ...        ...      ...
# 1194  0.122293        1
# 1195  0.191488        1
# 1196  0.175776        1
# 1197  0.183483        1
# 1198  0.183502        1
#
# [1164 rows x 15 columns]

# %%
selected_features = ['Num.Rep.','SessionLength','Avg.Sess.', 'Avg.Cons.', 'temperature', 'Avg. Humidity', 'Avg Wind Speed(mph)','Wind Bearing(degrees)','Visibility(km)','Pressure(millibar)','Battery_Pack Kwh','FastCharge_KmH','newkWh','anomaly']

# %%
X = ev_data[selected_features]

# %%
X
# Out:
#       Num.Rep.  SessionLength  Avg.Sess.  Avg.Cons.  temperature
# 0        11.13           2.20       3.55       6.44        24.37  \
# 1        13.75          11.19       3.55       6.44        24.37
# 2        13.76          10.33       3.54       6.44        24.37
# 3        14.62           9.31       3.55       6.44        24.37
# 4        14.68           8.38       3.55       6.44        24.37
# ...        ...            ...        ...        ...          ...
# 1194     16.00           3.22       2.57       3.62        35.98
# 1195     19.00           1.51       2.41       4.07        35.98
# 1196     12.00           3.28       2.70       3.85        35.98
# 1197     13.00           1.89       2.42       3.93        35.98
# 1198     12.00           2.95       2.95       4.03        35.98
#
#       Avg. Humidity  Avg Wind Speed(mph)  Wind Bearing(degrees)
# 0             34.85                13.54                    300  \
# 1             34.85                13.54                    300
# 2             34.85                13.54                    300
# 3             34.85                13.54                    300
# 4             34.85                13.54                    300
# ...             ...                  ...                    ...
# 1194          40.55                10.35                    305
# 1195          40.55                10.35                    305
# 1196          40.55                10.35                    305
# 1197          40.55                10.35                    305
# 1198          40.55                10.35                    305
#
#       Visibility(km)  Pressure(millibar)  Battery_Pack Kwh  FastCharge_KmH
# 0                9.9             1004.55              70.0             940  \
# 1                9.9             1004.55              45.0             250
# 2                9.9             1004.55              75.0             620
# 3                9.9             1004.55              74.0             560
# 4                9.9             1004.55              28.5             190
# ...              ...                 ...               ...             ...
# 1194            16.1             1005.18              45.0             260
# 1195            16.1             1005.18              65.0             345
# 1196            17.3             1005.18             118.0             670
# 1197            17.3             1005.18              28.0             215
# 1198            17.3             1005.18              70.0             800
#
#         newkWh  anomaly
# 0     0.131611        1
# 1     0.078603        1
# 2     0.187820        1
# 3     0.187508        1
# 4     0.076597        1
# ...        ...      ...
# 1194  0.122293        1
# 1195  0.191488        1
# 1196  0.175776        1
# 1197  0.183483        1
# 1198  0.183502        1
#
# [1164 rows x 14 columns]

# %%
from sklearn.cluster import KMeans

# %%
sse = []

# Try different values of k and compute the sum of squared distances
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# Plot the elbow curve
plt.plot(range(1, 11), sse, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Sum of Squared Distances')
plt.title('Elbow Method for Optimal k')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
num_clusters = 2 # Number of clusters
kmeans = KMeans(n_clusters=num_clusters)
clusters = kmeans.fit_predict(X)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
ev_data['cluster'] = clusters
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9088\2309874573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ev_data['cluster'] = clusters

# %% [markdown]
# #Splitting the features and target

# %%
Y = ev_data['kWhDelivered']

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standardized_data = scaler.transform(X)

# %%
print(standardized_data)
# Out:
# [[-0.93548255 -0.44890018  2.98515362 ...  1.52856947 -0.43406956
#    0.10627571]
#  [-0.27630606  2.80337287  2.98515362 ... -1.43884791 -1.38472671
#    0.10627571]
#  [-0.27379012  2.49225442  2.93994638 ...  0.1523759   0.57399434
#    0.10627571]
#  ...
#  [-0.7165957  -0.0581933  -0.85746171 ...  0.36740614  0.35799158
#    0.10627571]
#  [-0.46500162 -0.56104753 -2.1232644  ... -1.58936909  0.49621324
#    0.10627571]
#  [-0.7165957  -0.17757596  0.27271927 ...  0.92648478  0.49654813
#    0.10627571]]

# %%
X = standardized_data
Y = ev_data['kWhDelivered']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
regressor = RandomForestRegressor(n_estimators=100)

# %%
regressor.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
test_data_prediction = regressor.predict(X_test)

# %%
print(test_data_prediction)
# Out:
# [ 6.504   5.2494  9.4342  4.993   8.7431 14.8558  7.4385  4.9297  2.7864
#   6.5888  3.137   5.644   5.9345  2.4276  9.2932  3.9428  9.6702  6.6708
#   6.2251  4.7683  4.5551  7.3371  4.3051 15.5807 12.5179  4.6517  6.3585
#  12.5979  5.2857  5.3042  1.5249  6.3893  6.6203 11.9263  6.338   4.8358
#   3.1254  6.7248  3.6807  6.3822  6.0178  6.4403  5.1433  9.0443  4.7865
#   5.0239  3.663   4.4369  5.1011  4.5041  5.251   2.3696  3.2784  6.3428
#   7.8729  4.6619  5.4081  4.9908  6.4249  6.5979  4.6247 11.2464  4.6579
#  10.6978  6.6575  4.616   6.3492  4.5595  6.9115  6.425   4.5802 10.9253
#   6.7854  3.6023  6.7904 11.7675  4.8657  4.9883  5.2344 12.5295  4.9446
#   5.3185  6.6268 10.304   5.1896  4.898   3.5695 15.8473 11.4693  6.4744
#   1.4199  6.4063  4.6833  4.8712 11.7378  6.7294  3.6859  5.9238  5.137
#   5.0429  5.2635  4.0132  0.0168 11.2293  4.481   3.5835  5.8834  9.3277
#   6.5039  6.3528  6.62    0.0339  3.1721  4.4693  4.6019  5.4892  6.3715
#   6.4421  0.866   2.1379  5.9659  3.5049  3.9683  2.2084  3.2524  6.7093
#   4.9598  4.5763  4.6049  7.3329  5.3553  4.5236  0.9948  4.555   3.7259
#   4.9092 10.0247  6.454   6.4283  5.1989  3.6595  6.5686  6.4154  3.0392
#   3.553   2.8268  5.0026  6.7258  6.778   5.9892  4.2831  6.6433  3.2905
#   2.9243  5.1657  0.8292  6.3639  2.6729  3.5043  4.1398  4.5581  6.1416
#   6.8426  9.8877  6.4039  2.2711  5.9959  4.5658  5.4248  3.9622  5.1808
#   3.713   5.2056 11.8018  6.6051  2.9844  5.9574  6.5269  5.0387  6.1671
#   4.8062  2.8425 10.4489  6.3725  7.0959  3.7005  6.4371  3.7671  6.6835
#   1.3632  5.2558  4.4666  4.9175  3.2273  6.6905  6.4828  6.4724  6.6318
#   4.2659  6.7507  6.5895  2.7413  3.2515 15.367   4.7145  4.2623 10.989
#   6.7738  5.1722  3.665   6.6041  2.7972  3.4102  0.1601  6.4892  2.3363
#   6.5842 10.9482  6.3637  1.5479  6.3375  4.6601  6.4487  6.4389  3.7333
#   2.1217  4.9121  4.2555  9.8525 12.4667 15.4192  0.406   5.3851]

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='red', label = 'Actual Value')
plt.plot(test_data_prediction, color='green', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('Energy')
plt.legend()
plt.show()

# %%
def smape(actual, predicted):
    """
    Calculate SMAPE (Symmetric Mean Absolute Percentage Error) for actual and predicted values.
    """
    n = len(actual)
    ape = np.abs(actual - predicted) / ((np.abs(actual) + np.abs(predicted)) / 2)
    smape = (1 / n) * np.sum(2 * ape) * 100
    return smape

# %%
#Training Scores
training_data_prediction = regressor.predict(X_train)

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 0.36124135338345875

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 0.7023316933366253

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9586091960243571

# %%
smape_score = smape(Y_train, training_data_prediction)
print("SMAPE score: ", smape_score)
# Out:
# SMAPE score:  20.792835317403878

# %%
#Test Scores
mean_absolute_error(Y_test, test_data_prediction)
# Out:
# 0.9903163090128759

# %%
rms = sqrt(mean_squared_error(Y_test, test_data_prediction))

# %%
print(rms)
# Out:
# 2.1210647425938416

# %%
test_d_prediction = regressor.predict(X_train)

# %%
# R squared error
error_score = metrics.r2_score(Y_test, test_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.5934682952241344

# %%
def smape(actual, predicted):
    """
    Calculate SMAPE (Symmetric Mean Absolute Percentage Error) for actual and predicted values.
    """
    actual = np.array(actual)
    predicted = np.array(predicted)
    return 100/len(actual) * np.sum(2 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted)))

# %%
smape_score = smape(Y_test, test_data_prediction)
print("SMAPE score: ", smape_score)
# Out:
# SMAPE score:  22.337514773405754

# %%
# Plotting the actual values
plt.plot(Y_test, label='Actual', marker='o')

# Plotting the predicted values
plt.plot(test_data_prediction, label='Predicted', marker='s')

# Setting labels and title
plt.xlabel("Data Points")
plt.ylabel("Values")
plt.title("Actual vs Predicted")

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
#Visualising
sns.regplot(x=Y_test, y=test_data_prediction)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %% [markdown]
# #SVM

# %%
svr = SVR(kernel='rbf', C=10, gamma=0.1, epsilon=0.1)
svr.fit(X_train,Y_train)
# Out:
# SVR(C=10, gamma=0.1)

# %%
y_pred = svr.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)

# %%
print(y_pred)
# Out:
# [ 6.24620668  5.13231136  9.26155627  5.75310251  9.16784681 15.16290888
#   9.94591541  5.44094941  4.79357486  5.22101039  2.11452889  6.12092583
#   4.58447094  4.22165639 10.04454371  5.0962486  10.58207848  5.57268768
#   7.90682713  4.52947931  4.03439907  6.58678495  6.57186509 15.36868796
#   9.07775944  5.55985381  6.56048623 13.05482661  6.28253979  6.25621801
#   0.34563341  5.94761715  5.7172351   8.98382719  6.51900849  5.09213857
#   2.4327679   6.48789139  4.11934864  5.92306059  5.9063558   6.9926694
#   5.57623031  9.07569333  4.74948138  5.84769846  3.12861752  4.50917197
#   4.90198183  4.77222136  5.7268647   0.87580346  2.70755812  6.08933798
#  12.44802802  7.26269692  4.03988623  4.50015174  5.84977711  6.44395734
#   5.07901728  8.02671044  3.70248991  7.8085155   5.90343927  3.32738829
#   6.39403626  3.39873224  6.86736128  6.34694032  3.39329282  8.77948913
#   6.82616199  3.67579966  6.57907408 10.76258793  5.68570108  3.3995294
#   5.27764187 11.85511246  4.30973007  5.69485262  6.1393766   9.48029144
#   5.18385924  5.49096923  2.41821446 16.04842532 10.10966745  7.10842107
#   6.2439941   6.66928187  4.76388972  4.26729702  9.43567388  6.90455908
#   5.39811184  5.93887771  4.4092988   5.34900228  4.66147772  4.27667404
#   3.60149541 14.39737362  4.674473    3.61263315  5.84533808  8.46758427
#   5.0488293   6.83416203  9.22381009  3.08177881  2.84610919  3.46356341
#   4.81235717  5.27039578  5.59733261  7.00807725  5.43416592  2.13636358
#   4.50800573  3.75059989  4.60085577  1.671326    4.28902647  4.53696613
#   5.13971646  2.57424132  4.27359963  2.79427648  5.62600397  4.91533923
#   4.1364015   4.8060336   4.13815981  5.25524453  9.96457257  6.22647791
#   6.73340522  3.06463057  3.85047065  6.25004159  5.77109686  2.15449967
#   6.13853495  2.87618546  5.04232173  6.39222293  6.92804706  6.00102311
#   4.80328686  5.56736138  5.10656296  4.16812692  3.65349297  6.45146661
#   6.31424892  6.54359335  3.80332661  4.05251141  4.91679131  6.03965178
#   6.92561009 12.60802347  6.63014078  2.30085607  6.40212341  5.9428257
#   0.17306563  4.56620635  5.62566096  2.24263268  5.86576414 11.567601
#   5.90303976  2.18743692  5.96980333  5.50291769  4.63553709  3.76373636
#   6.61036555  5.15434854 10.76335073  5.51979063 10.07781803  4.07268953
#   7.05456419  4.16120591  8.39982208  6.13931216  6.12201753  3.91001864
#   5.26289369  5.37596565  6.64385434  6.23715357  5.19433641  6.25769414
#   5.09977568  6.56560709  7.29413562  2.59248832  2.14960856 15.00408879
#   5.00122237  4.68858454 10.68832872  6.12446548  5.78262357  3.07584515
#   6.97515458  7.50108185  3.99310216  5.65545091  5.28111349  1.63331945
#   6.45686129  7.33848934  6.80298281  1.35020255  5.59645363  4.80151869
#   6.61719399  6.08395844  4.27990665  1.60726459  4.79470622  4.93802935
#  12.09546376 15.85472877 14.99083568 10.13445144  4.01850247]

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(y_pred, color='green', label='Predicted Value')
plt.title('Actual vs Predicted')
plt.xlabel('Number of values')
plt.ylabel('Energy')
plt.legend()
plt.show()

# %%
mean_absolute_error(Y_test, y_pred)
# Out:
# 1.4904683631500433

# %%
rms = sqrt(mean_squared_error(Y_test, y_pred))

# %%
print(rms)
# Out:
# 2.6602619566614085

# %%
# R squared error
error_score = metrics.r2_score(Y_test, y_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.36050761263549524

# %%
smape_score = smape(Y_test, y_pred)
print("SMAPE score: ", smape_score)
# Out:
# SMAPE score:  32.12447974883652

# %%
# Plotting the actual values
plt.plot(Y_test, label='Actual', marker='o')

# Plotting the predicted values
plt.plot(y_pred, label='Predicted', marker='s')

# Setting labels and title
plt.xlabel("Data Points")
plt.ylabel("Values")
plt.title("Actual vs Predicted")

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
#Visualising
sns.regplot(x=Y_test, y=y_pred)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %% [markdown]
# #XGB

# %%
# loading the model
xb_model = XGBRegressor()

# %%
# training the model with X_train
xb_model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
test_prediction = xb_model.predict(X_test)

# %%
print(test_prediction)
# Out:
# [ 6.577191    5.3257036  12.201833    4.096337   10.123      14.974995
#   8.718178    4.8660583   2.8099852   6.5590467   2.9341693   5.2835402
#   5.8638077   2.0508735   9.069902    3.903092    9.07249     6.5565042
#   6.5174403   5.2645884   4.3619814   8.175262    3.5994313  15.554381
#  12.9654045   3.8674755   6.6203794  12.020804    5.633286    5.773954
#   3.1483982   6.4918265   6.571989   10.31691     6.169429    5.183753
#   3.1657836   6.696306    2.8562684   6.5068297   6.06153     6.224359
#   4.499141    7.391697    4.677674    4.394904    3.1723037   4.4294515
#   4.897671    4.422251    5.531332    2.3307595   3.1331336   6.403442
#   9.57615     9.300863    5.029978    4.8434615   6.3127494   6.1546507
#   4.3872075  13.102969    4.080232   10.327878    6.622761    4.464233
#   6.3020034   4.010538    6.749306    6.6502485   3.409979   11.475525
#   6.8611927   3.250115    6.8304     11.81479     4.8274755   4.9467974
#   5.4930463  12.694588    4.7054358   5.5778174   6.479341   12.222639
#   5.137507    5.066428    3.416487   15.941633   11.629125    6.395146
#   0.8056859   6.280682    4.124854    4.758261   13.700411    6.6390486
#   4.3035164   5.93099     4.9451394   4.9186406   5.0890856   4.1425333
#   0.22688594 11.248038    4.2275667   3.4515007   5.8910937   8.278094
#   6.6851525   6.6490183   6.0986648   0.06311518  2.8524299   4.234366
#   4.758416    7.059512    6.205315    6.3594875   0.8533965   1.8997021
#   6.4294705   3.6167216   3.8407762   1.0435487   3.4355595   6.6025515
#   4.8778      4.470106    4.39384     1.3918235   5.480461    4.9441705
#  -0.07718978  4.26009     3.8525963   5.0363665  11.956892    6.4856296
#   6.335765    6.045326    3.3669364   6.444457    6.0684557   3.535838
#   1.2823371   2.5880854   5.0456476   6.5138965   6.738306    5.9890447
#   3.8129241   6.7221966   2.8173015   2.564154    5.1034894   0.7398875
#   6.402401    2.2386453   3.4547994   3.8583908   4.270855    6.309822
#   6.865974    9.366925    6.379287    1.2411913   5.920177    5.377742
#   5.794148    3.4002554   5.110854    3.523775    5.2935486  13.058376
#   6.6647315   3.0838969   5.819648    6.7443395   5.122016    6.4888606
#   5.5256267   2.4518178  11.31755     6.3395762   6.685267    3.1087103
#   6.3511195   3.1603925   6.6871877   2.2277212   5.411172    4.1058273
#   4.5999427   1.9820127   6.6007133   6.4896836   6.110149    6.9853797
#   4.1957035   6.9228544   7.2435603   3.0912669   2.812056   15.582281
#   4.74286     4.1550584  10.805201    6.9877844   5.234621    3.3686898
#   6.5925426  -0.5873418   2.903134    0.1794536   6.493115    2.2227757
#   6.7880487  11.298069    6.4793944   0.20606256  6.592136    4.249713
#   6.3616962   6.384627    3.1030679   0.97072643  4.98039     4.454619
#   9.533096   13.400646   16.255459    0.2591677   6.552887  ]

# %%
Y_test = list(Y_test)

# %%
plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(test_prediction, color='green', label='Predicted Value')
plt.title('Actual  vs Predicted ')
plt.xlabel('Number of values')
plt.ylabel('Energy')
plt.legend()
plt.show()

# %%
#Training Scores
training_data_prediction = xb_model.predict(X_train)

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 0.04417397635888856

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 0.06299217098378748

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9996670396792545

# %%
smape_score = smape(Y_train, training_data_prediction)
print("SMAPE score: ", smape_score)
# Out:
# SMAPE score:  3.390405326443652

# %%
#Test Scores
mean_absolute_error(Y_test, test_prediction)
# Out:
# 0.9527312456832423

# %%
rms = sqrt(mean_squared_error(Y_test, test_prediction))

# %%
print(rms)
# Out:
# 2.0965536474223985

# %%
# R squared error
error_score = metrics.r2_score(Y_test, test_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.6028097941832957

# %%
smape_score = smape(Y_test, test_prediction)
print("SMAPE score: ", smape_score)
# Out:
# SMAPE score:  24.1098409581182

# %%
# Plotting the actual values
plt.plot(Y_test, label='Actual', marker='o')

# Plotting the predicted values
plt.plot(test_prediction, label='Predicted', marker='s')

# Setting labels and title
plt.xlabel("Data Points")
plt.ylabel("Values")
plt.title("Actual vs Predicted")

# Displaying the legend
plt.legend()

# Showing the plot
plt.show()

# %%
#Visualising
sns.regplot(x=Y_test, y=test_prediction)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %% [markdown]
# #ANN

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
# layers
model=Sequential()
model.add(Dense(units = 14, kernel_initializer = 'uniform', activation = 'relu', input_dim = 14))
#model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))

# %%
# Compile the model
model.compile(loss='mean_absolute_error', optimizer='adam')

# %%
# Train the model on the training dataset
model.fit(X_train, Y_train, epochs=1000, batch_size=64, verbose=0)

# %%
# Use the trained model to make predictions on the test dataset
Y_pred = model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 2ms/step

# %%
print(Y_pred)
# Out:
# [[ 6.6224008 ]
#  [ 5.177905  ]
#  [ 9.418163  ]
#  [ 7.557904  ]
#  [ 9.199482  ]
#  [15.837456  ]
#  [ 0.6723561 ]
#  [ 4.8727965 ]
#  [ 2.7636094 ]
#  [ 7.037412  ]
#  [ 2.8945334 ]
#  [ 4.850251  ]
#  [ 5.3870544 ]
#  [ 6.518339  ]
#  [ 9.9897995 ]
#  [ 4.2288704 ]
#  [10.848817  ]
#  [ 5.524056  ]
#  [ 8.380797  ]
#  [ 4.4990115 ]
#  [ 5.2118826 ]
#  [ 7.9757857 ]
#  [ 6.975015  ]
#  [13.909188  ]
#  [10.560754  ]
#  [ 3.73131   ]
#  [ 6.349933  ]
#  [15.288668  ]
#  [ 5.4185376 ]
#  [ 4.7053137 ]
#  [ 3.0300734 ]
#  [ 7.218849  ]
#  [ 6.2745585 ]
#  [ 9.708355  ]
#  [ 6.6322546 ]
#  [ 4.7359967 ]
#  [ 3.0222182 ]
#  [ 6.5104933 ]
#  [ 3.9772704 ]
#  [ 6.410944  ]
#  [ 6.0818048 ]
#  [ 6.877295  ]
#  [ 4.723352  ]
#  [11.221112  ]
#  [ 4.8500915 ]
#  [ 4.1919055 ]
#  [ 3.192831  ]
#  [ 4.6433682 ]
#  [ 4.6698813 ]
#  [ 4.395916  ]
#  [ 4.8062873 ]
#  [ 2.6988587 ]
#  [ 2.8626375 ]
#  [ 6.327752  ]
#  [ 9.660765  ]
#  [ 8.356873  ]
#  [ 4.1227202 ]
#  [ 4.715279  ]
#  [ 6.5736547 ]
#  [ 6.680754  ]
#  [ 4.716655  ]
#  [10.453121  ]
#  [ 4.4644456 ]
#  [ 9.450778  ]
#  [ 6.2439427 ]
#  [ 0.33391595]
#  [ 6.6607842 ]
#  [ 3.047061  ]
#  [ 6.4058766 ]
#  [ 5.9322915 ]
#  [ 2.4295962 ]
#  [ 5.7423644 ]
#  [ 6.496094  ]
#  [ 3.5888176 ]
#  [ 6.6454444 ]
#  [12.645905  ]
#  [ 5.1403937 ]
#  [ 4.999527  ]
#  [ 4.9211955 ]
#  [13.960632  ]
#  [ 4.9891124 ]
#  [ 5.0290914 ]
#  [ 6.5098424 ]
#  [11.017206  ]
#  [ 4.712651  ]
#  [ 5.0413136 ]
#  [ 2.927028  ]
#  [16.203661  ]
#  [ 9.657819  ]
#  [ 6.7365203 ]
#  [10.597678  ]
#  [ 6.9664702 ]
#  [ 4.5361733 ]
#  [ 4.078424  ]
#  [10.83629   ]
#  [ 6.693354  ]
#  [ 9.504924  ]
#  [ 5.7453218 ]
#  [ 4.340853  ]
#  [ 4.80426   ]
#  [ 5.014395  ]
#  [ 4.1612544 ]
#  [ 5.5266633 ]
#  [11.522591  ]
#  [ 4.3884125 ]
#  [ 3.18225   ]
#  [ 5.6919847 ]
#  [10.254227  ]
#  [ 6.5113897 ]
#  [ 6.7289686 ]
#  [ 7.3367743 ]
#  [ 0.05560563]
#  [ 2.7046533 ]
#  [ 3.3747716 ]
#  [ 4.925362  ]
#  [ 4.891017  ]
#  [ 6.0196075 ]
#  [ 6.7118893 ]
#  [ 7.521399  ]
#  [ 1.6196156 ]
#  [ 5.299252  ]
#  [ 5.2147584 ]
#  [ 4.119894  ]
#  [ 5.7556124 ]
#  [ 1.1482055 ]
#  [ 6.8437033 ]
#  [ 4.868432  ]
#  [ 4.5624433 ]
#  [ 4.558916  ]
#  [ 2.9567266 ]
#  [ 5.497499  ]
#  [ 4.184669  ]
#  [ 4.3495717 ]
#  [ 4.909037  ]
#  [ 3.6516068 ]
#  [ 4.988621  ]
#  [11.565238  ]
#  [ 6.1956325 ]
#  [ 6.6726804 ]
#  [ 4.6135883 ]
#  [ 3.8341618 ]
#  [ 6.426727  ]
#  [ 6.2749786 ]
#  [ 2.707752  ]
#  [ 5.9135113 ]
#  [ 2.766982  ]
#  [ 4.418858  ]
#  [ 6.409758  ]
#  [ 6.847003  ]
#  [ 6.0677676 ]
#  [ 4.249509  ]
#  [ 6.225466  ]
#  [ 6.184022  ]
#  [ 3.6982188 ]
#  [ 4.633033  ]
#  [10.168063  ]
#  [ 6.4872746 ]
#  [ 0.85482025]
#  [ 3.2838714 ]
#  [ 3.7651381 ]
#  [ 4.698938  ]
#  [ 5.7023573 ]
#  [ 6.563087  ]
#  [12.667967  ]
#  [ 6.2191925 ]
#  [ 9.464243  ]
#  [ 5.6737328 ]
#  [ 1.8770263 ]
#  [ 2.106248  ]
#  [ 3.8471591 ]
#  [ 5.372801  ]
#  [ 3.1302528 ]
#  [ 4.9441347 ]
#  [ 9.910679  ]
#  [ 6.266059  ]
#  [ 2.7605915 ]
#  [ 5.8806148 ]
#  [ 6.198312  ]
#  [ 4.841879  ]
#  [ 6.1155734 ]
#  [ 4.7362723 ]
#  [ 5.785351  ]
#  [12.213928  ]
#  [ 6.5040245 ]
#  [ 4.031556  ]
#  [ 3.8995125 ]
#  [ 6.991759  ]
#  [ 3.7741325 ]
#  [ 7.1795735 ]
#  [10.294985  ]
#  [ 4.7299027 ]
#  [ 4.561603  ]
#  [ 4.9585457 ]
#  [ 5.53894   ]
#  [ 6.4277596 ]
#  [ 6.7491927 ]
#  [ 6.915674  ]
#  [ 6.1221986 ]
#  [ 4.3554883 ]
#  [ 6.6042976 ]
#  [ 9.775068  ]
#  [ 1.9575968 ]
#  [ 5.8161974 ]
#  [ 9.553091  ]
#  [ 4.402434  ]
#  [ 4.186764  ]
#  [11.0040245 ]
#  [ 2.0174584 ]
#  [ 4.960726  ]
#  [ 4.498543  ]
#  [ 6.417691  ]
#  [ 8.175928  ]
#  [ 2.0831456 ]
#  [ 4.8226943 ]
#  [ 6.081766  ]
#  [ 2.8394148 ]
#  [ 6.318547  ]
#  [ 6.2481737 ]
#  [ 7.1050773 ]
#  [ 2.318553  ]
#  [ 7.155127  ]
#  [ 3.9018059 ]
#  [ 6.5606976 ]
#  [ 6.3433266 ]
#  [ 4.065638  ]
#  [ 6.9608655 ]
#  [ 5.040911  ]
#  [ 4.4142957 ]
#  [13.118948  ]
#  [14.022123  ]
#  [11.745199  ]
#  [13.662083  ]
#  [ 2.4450212 ]]

# %%
#Training Scores
training_data_prediction = model.predict(X_train)
# Out:
# 30/30 [==============================] - 0s 1ms/step

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 0.8903935552826382

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 1.954076490204734

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.6795926662129621

# %%
def smape(actual, predicted):
    """
    Calculate SMAPE (Symmetric Mean Absolute Percentage Error) for actual and predicted values.
    """
    actual = np.array(actual)
    predicted = np.array(predicted)
    return np.mean((np.abs(actual - predicted) / (np.abs(actual) + np.abs(predicted))) * 2) * 100

# %%
smape_score = smape(Y_test, training_data_prediction )
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 63.44896970764783

# %%
#Test Scores
mean_absolute_error(Y_test, Y_pred)
# Out:
# 1.5584814791886592

# %%
rms = sqrt(mean_squared_error(Y_test, Y_pred))

# %%
print(rms)
# Out:
# 2.9314878919553795

# %%
# R squared error
error_score = metrics.r2_score(Y_test, Y_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.22346187857472388

# %%
smape_score = smape(Y_test, Y_pred)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 60.05644313709109

# %%
#Visualising
sns.regplot(x=Y_test, y=Y_pred)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %% [markdown]
# #KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
k = 8
knn = KNeighborsRegressor(n_neighbors=k)
knn.fit(X_train, Y_train)
knn_pred = knn.predict(X_test)

# %%
#Train Scores
training_data_prediction = knn.predict(X_train)

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 1.6955571965628358

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 2.5365527745706498

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.4601076998302416

# %%
smape_score = smape(Y_train, training_data_prediction)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 32.29043809060452

# %%
#test Scores
mean_absolute_error(Y_test, knn_pred)
# Out:
# 1.8579989270386263

# %%
sqrt(mean_squared_error(Y_test, knn_pred))
# Out:
# 2.740391672659502

# %%
# R squared error
error_score = metrics.r2_score(Y_test, knn_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.32140313404575893

# %%
smape_score = smape(Y_test, knn_pred)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 37.87433660731243

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
k = 9
knn = KNeighborsRegressor(n_neighbors=k)
adaboost = AdaBoostRegressor(estimator=knn, n_estimators=50, learning_rate=0.1)
adaboost.fit(X_train, Y_train)
ada_pred = adaboost.predict(X_test)

# %%
#Train Scores
training_data_prediction = adaboost.predict(X_train)

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 1.6791920276882681

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 2.3663937237517105

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.530113099142548

# %%
smape_score = smape(Y_train, training_data_prediction)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 32.91403191571367

# %%
#Test Scores
mean_absolute_error(Y_test, ada_pred)
# Out:
# 1.8689270386266097

# %%
sqrt(mean_squared_error(Y_test, ada_pred))
# Out:
# 2.7316344558140915

# %%
# R squared error
error_score = metrics.r2_score(Y_test, ada_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.32573326307357775

# %%
smape_score = smape(Y_test, ada_pred)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 38.69057919252443

# %%
#Visualising
sns.regplot(x=Y_test, y=ada_pred)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %% [markdown]
# # Ensemble Learning

# %%
stack_regressor = StackingRegressor(estimators=[('rf', regressor), ('xgb', xb_model)])
stack_regressor.fit(X_train, Y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor()),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...))])

# %%
predictions = stack_regressor.predict(X_test)

# %%
print(predictions)
# Out:
# [ 6.52466064  5.27246782 11.31674242  4.30785268  9.56025985 14.83350352
#   8.23402328  4.87628542  2.78223576  6.55955116  2.97538283  5.44189495
#   5.86866407  2.22401122  9.03875463  3.86062861  9.41332463  6.57235196
#   6.45779559  5.083834    4.4101611   7.77542546  3.85326015 15.35295024
#  12.63746329  3.95684734  6.5295938  12.09569319  5.45030322  5.49571478
#   2.59722779  6.49057866  6.55912064 10.67640221  6.20062369  5.04151819
#   3.10962878  6.67988505  3.1109764   6.43442081  6.01918659  6.27234395
#   4.72860489  7.74687455  4.71119569  4.55918847  3.28099887  4.42974954
#   4.95757084  4.41249524  5.41812919  2.32930039  3.17010585  6.34468604
#   8.86245024  7.63778025  5.02373283  4.86245305  6.31793376  6.27220777
#   4.43675511 12.31446928  4.20918934 10.52827143  6.60350771  4.30203838
#   6.26864265  4.11316843  6.77850071  6.53816101  3.79640622 11.0880282
#   6.80036111  3.36644568  6.78212868 11.77618651  4.81272714  4.92750857
#   5.32186294 12.55514022  4.76860862  5.41493985  6.51117515 11.68459562
#   5.09555149  4.95416278  3.35918528 15.71191188 11.47747418  6.40070736
#   1.01318051  6.29264648  4.27512693  4.77190079 12.92915896  6.62949744
#   4.16646271  5.89721732  4.99511628  4.92369229  5.12914832  4.18770603
#   0.14432676 11.14586966  4.25400803  3.46495309  5.8638175   8.84785216
#   6.58696117  6.52410294  6.08332836  0.050392    2.92029313  4.28119516
#   4.66839263  6.59262199  6.22317972  6.37478089  0.84488633  1.9284556
#   6.18549287  3.49043019  3.8507479   1.5101241   3.2208492   6.59148449
#   4.86999518  4.50008171  4.40162862  3.10283852  5.42627162  4.80195749
#   0.47323692  4.36062753  3.78743056  4.98224462 11.27584945  6.43826836
#   6.34089416  5.69900372  3.45233221  6.43946365  6.16419599  3.35165156
#   1.87542255  2.66121475  5.00857459  6.56348408  6.71555857  5.96185304
#   4.04393605  6.6584713   2.93452579  2.91250864  5.11996333  0.76355116
#   6.36769989  2.31983034  3.49076954  3.96483149  4.3994553   6.24446101
#   6.82923933  9.59174714  6.36473068  1.5763971   5.90653895  5.06872578
#   5.3631162   3.57614096  5.10388702  3.46808851  5.21824524 12.53465325
#   6.6057272   3.0141934   5.84198129  6.66013964  5.07250925  6.34181557
#   5.19418351  2.53713643 11.1057003   6.34888467  6.88766652  3.29028595
#   6.35958033  3.33586339  6.52741467  2.14662111  5.34267043  4.22224265
#   4.64843706  2.39930597  6.60053693  6.46244973  6.20544991  6.82041319
#   4.23225898  6.81635413  6.98113892  2.92421797  2.99650997 15.64471469
#   4.72337271  4.16986127 10.81278022  7.07716093  5.19739437  3.4533424
#   6.56418836  0.37153214  3.09913251  0.15857177  6.48135508  2.24815136
#   6.68883113 10.82698057  6.41334224  0.69769645  6.48776645  4.38802132
#   6.36438616  6.3679917   3.3482143   1.54373415  4.92625224  4.35352432
#   9.3759608  13.05306557 15.83238136  0.28645209  6.12193134]

# %%
#Train Scores
training_data_prediction = stack_regressor.predict(X_train)

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 0.15358421480819923

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 0.27189735331114984

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9937966070962193

# %%
smape_score = smape(Y_train, training_data_prediction)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 6.352778040943019

# %%
#Test Scores
mean_absolute_error(Y_test, predictions)
# Out:
# 0.9270327257521407

# %%
rms = sqrt(mean_squared_error(Y_test, predictions))

# %%
print(rms)
# Out:
# 2.0662093128458383

# %%
# R squared error
error_score = metrics.r2_score(Y_test, predictions)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.6142240045157739

# %%
smape_score = smape(Y_test, predictions)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 21.352671865943027

# %%
#Visualising
sns.regplot(x=Y_test, y=predictions)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %%
stack_regressor = StackingRegressor(estimators=[('rf', regressor),('svm',svr)])
stack_regressor.fit(X_train, Y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor()),
#                               ('svm', SVR(C=10, gamma=0.1))])

# %%
pred=stack_regressor.predict(X_test)

# %%
print(pred)
# Out:
# [ 6.47809877  5.15449198  9.66465011  5.23046873  9.20909846 15.53537694
#   7.86554532  5.02747549  2.97667979  6.4877616   2.69199538  5.62262807
#   5.73325328  2.27664253  9.2986317   3.99811192 10.67719441  6.49337089
#   6.08884679  4.63699682  4.42842582  7.29953552  4.55757423 16.21876448
#  11.77872417  4.4975077   6.3201587  12.31108395  5.21106458  5.23353193
#   0.89235873  6.04283525  6.5033883  11.26636469  6.34237918  4.64315195
#   2.92426802  6.67549862  3.58855499  6.31710396  5.977885    6.50522746
#   5.25698156  8.93364507  4.71977847  4.94210636  3.48798487  4.36262562
#   4.96020498  4.42860648  5.27375082  1.88554326  2.88732286  6.27269811
#   9.63703815  6.25171808  4.92188383  4.84985061  6.28128192  6.48160122
#   4.60951796 10.37342187  4.31940193 10.44407094  6.55488997  4.87828028
#   6.32257099  4.3157287   6.93428683  6.3843482   4.57141561 11.01649455
#   6.80448811  3.44224788  6.78129944 11.97574503  4.9474759   4.53967538
#   5.06389121 12.77728429  4.71930602  5.26518299  6.58408109 10.38491633
#   5.05697511  4.84551665  3.13576559 16.15403599 12.13544465  6.60718498
#   1.81788047  6.44111913  4.57084562  4.62864981 11.84433928  6.75098747
#   3.90874797  5.92131003  4.93495038  4.93954268  5.11125841  4.05491159
#   0.24466638 12.23933391  4.44569609  3.52571078  5.85811209  9.13695028
#   6.26710176  6.43692064  7.66549197  0.17999985  2.73654185  3.96073633
#   4.51663766  5.20693355  6.20812446  6.54184819  1.20471102  1.79125449
#   5.64461837  3.00776502  3.9445525   1.97800671  2.70633322  6.3746021
#   4.87667118  4.16747684  4.42441919  5.84746084  5.27173899  4.55040628
#   2.11861543  4.44244785  3.61870582  4.86949829 10.13872488  6.40929138
#   6.47325829  4.65628541  3.50623334  6.47996161  6.31475465  2.63820365
#   3.87917144  2.62363396  4.88863755  6.70780619  6.8280955   5.95496106
#   4.26561788  6.44177169  3.20405537  3.12925931  4.80845864  1.33789958
#   6.37231467  2.94629957  3.45372945  3.9530486   4.53191755  6.15467183
#   6.89021613 10.94214638  6.41246738  1.95758923  5.97963393  4.36814169
#   4.01418988  3.85936542  5.17630665  3.48204396  5.19496687 12.2708766
#   6.53411742  2.73757     5.94706038  6.45718205  4.94120882  5.82520997
#   5.29139024  2.96007342 10.57160439  6.26993229  8.59786172  3.65793906
#   6.53902153  3.60027544  6.69996104  3.01197398  5.34964772  4.28199041
#   4.88966238  3.192441    6.67019815  6.44954289  6.27862966  6.55281203
#   4.38053679  6.69828736  6.80340629  3.0195589   2.90978082 15.68766642
#   4.72560768  4.18562313 11.43498814  7.23108975  5.17561131  3.40590876
#   6.58082973  3.83430362  3.20247492  0.69651942  6.35123155  1.96215626
#   6.61412384  9.67398864  6.42212255  1.36422579  6.23333266  4.68873932
#   6.47714655  6.36579497  3.66953181  2.34674336  4.79878361  4.13268984
#  10.14988392 13.18349456 16.14653349  1.42669765  5.72840481]

# %%
#Train Scores
training_data_prediction = stack_regressor.predict(X_train)

# %%
mean_absolute_error(Y_train, training_data_prediction)
# Out:
# 0.37475050381559694

# %%
sqrt(mean_squared_error(Y_train, training_data_prediction))
# Out:
# 0.7353996908957986

# %%
# R squared error
error_score = metrics.r2_score(Y_train, training_data_prediction)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9546198199510196

# %%
smape_score = smape(Y_train, training_data_prediction)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 12.094162440656635

# %%
#Test Scores
mean_absolute_error(Y_test, pred)
# Out:
# 1.0020458351896513

# %%
rms = sqrt(mean_squared_error(Y_test, pred))

# %%
print(rms)
# Out:
# 2.171058791491514

# %%
# R squared error
error_score = metrics.r2_score(Y_test, pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.5740783271024144

# %%
smape_score = smape(Y_test, pred)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 23.275768433673516

# %%
stack_regressor = StackingRegressor(estimators=[('rf', regressor), ('xgb',xb_model),('svm',svr)])
stack_regressor.fit(X_train, Y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor()),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None,
#                                             feature_types=None, gamma=None,
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
#                                             interaction_constraints=None,
#                                             learning_rate=None, max_bin=None,
#                                             max_cat_threshold=None,
#                                             max_cat_to_onehot=None,
#                                             max_delta_step=None, max_depth=None,
#                                             max_leaves=None,
#                                             min_child_weight=None, missing=nan,
#                                             monotone_constraints=None,
#                                             n_estimators=100, n_jobs=None,
#                                             num_parallel_tree=None,
#                                             predictor=None, random_state=None, ...)),
#                               ('svm', SVR(C=10, gamma=0.1))])

# %%
allpred=stack_regressor.predict(X_test)

# %%
#Test Scores
mean_absolute_error(Y_test, allpred)
# Out:
# 0.9316233939615916

# %%
sqrt(mean_squared_error(Y_test, allpred))
# Out:
# 2.082169701128774

# %%
# R squared error
error_score = metrics.r2_score(Y_test, allpred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.6082411498598841

# %%
smape_score = smape(Y_test, allpred)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 22.251140936801782

# %%
#Visualising
sns.regplot(x=Y_test, y=allpred)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %%
voting_reg = VotingRegressor(estimators=[('rf', regressor), ('xb',xb_model)])
voting_reg.fit(X_train, Y_train)
# Out:
# VotingRegressor(estimators=[('rf', RandomForestRegressor()),
#                             ('xb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           predictor=None, random_state=None, ...))])

# %%
Y_pred = voting_reg.predict(X_test)

# %%
print(Y_pred)
# Out:
# [ 6.53419544  5.30610181 10.98736639  4.49671842  9.60395007 14.92609733
#   8.1616389   4.94072917  2.80959258  6.61892337  3.09008465  5.42227012
#   5.94400384  2.28678676  8.93125121  3.85679595  9.74439487  6.62030212
#   6.31242016  5.08469418  4.5032907   7.64038123  3.94851564 15.47164069
#  12.50220226  4.05998775  6.46238972 12.2882022   5.440443    5.37607696
#   2.25649908  6.39801327  6.59359453 10.7939549   6.25266441  4.96517651
#   3.14744182  6.70640311  3.3037842   6.44466487  6.04286506  6.32292952
#   4.86012061  8.50889846  4.77138691  4.72185207  3.34235184  4.44337573
#   5.02398561  4.42642561  5.46231601  2.35362976  3.27251682  6.37367095
#   9.23007497  7.72428163  5.0387389   4.93398076  6.35652469  6.37402534
#   4.56080375 12.18463458  4.35876607 10.670939    6.62273039  4.51951646
#   6.32260169  4.16766905  6.8332531   6.54662426  4.09138955 11.36166245
#   6.81844635  3.44275746  6.8106     11.81009489  4.86323777  4.95724869
#   5.36572314 12.73559385  4.83216788  5.39935872  6.55697052 11.30546954
#   5.09550348  4.93816409  3.46954349 15.55461661 11.53536232  6.45922295
#   1.01994294  6.34084104  4.38347704  4.7868306  12.69730542  6.66972429
#   3.92960819  5.95004511  5.0161697   4.98512031  5.16434279  4.19661665
#   0.11819297 11.05116915  4.34308336  3.61665033  5.89084687  8.92274715
#   6.59267627  6.52770914  6.50018238  0.04515759  2.88101493  4.28093297
#   4.68765809  6.37265607  6.27525756  6.41934377  0.84949824  1.92360104
#   6.13923527  3.19621082  3.9124881   1.65817435  3.40702976  6.66047573
#   4.92174999  4.54895306  4.43846992  3.63551177  5.42663056  4.76518524
#   0.72350511  4.42039494  3.78599814  4.95353323 11.15679601  6.49446478
#   6.38553244  5.59321312  3.52921822  6.48242853  6.24592785  3.26851894
#   2.28206853  2.72014271  5.01067381  6.63824823  6.76210302  5.98537233
#   4.07541207  6.68019829  3.07235076  3.47987695  5.1604447   0.78704374
#   6.37155049  2.44547266  3.48834971  4.0377954   4.47267747  6.20541104
#   6.85953697  9.67251262  6.41124338  1.75449563  5.96708849  4.86452091
#   5.19072398  3.65302772  5.13802707  3.47808755  5.25157429 12.41773816
#   6.61886575  3.05699844  5.90312389  6.65986973  5.08825798  6.3085803
#   5.35961333  2.40820888 10.85867485  6.39108812  6.77473349  3.45540514
#   6.39725976  3.38334626  6.64929384  2.13381061  5.40483596  4.31401367
#   4.74622134  2.59785637  6.64445663  6.50279181  6.28257445  6.82383985
#   4.25545175  6.82932721  7.00073016  3.12198344  3.12957803 15.57104056
#   4.74972992  4.27207919 10.94920029  6.97824219  5.22206052  3.55199489
#   6.58257132  1.27367911  3.06801705  0.1892768   6.50490747  2.28928785
#   6.66397437 10.5755845   6.41314722  1.01768128  6.45331795  4.51780647
#   6.40814812  6.43681343  3.42203394  1.61431322  4.95759504  4.34060947
#   9.54969816 12.9954731  15.80192942  0.32323385  6.11859348]

# %%
mean_absolute_error(Y_test, Y_pred)
# Out:
# 0.9360623240626678

# %%
rms = sqrt(mean_squared_error(Y_test, Y_pred))

# %%
print(rms)
# Out:
# 2.081656454219812

# %%
# R squared error
error_score = metrics.r2_score(Y_test, Y_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.608434260188413

# %%
smape_score = smape(Y_test, Y_pred)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 21.47187305809812

# %%
residuals = Y_test - test_data_prediction
n = len(X_test)
p = 1  # Assuming only one predictor variable
SSE = np.sum(residuals ** 2)
SE = np.sqrt(SSE / (n - p - 1))
print(SE)
# Out:
# 2.1302270519494266

# %%
#Visualising
sns.regplot(x=Y_test, y=Y_pred)
plt.xlabel("Actual")
plt.ylabel('Predicted')
plt.title("ACtual vs predicted")
plt.show()

# %%
vote_regressor = VotingRegressor(estimators=[('rf', regressor), ('xgb',xb_model),('svm',svr)])
vote_regressor.fit(X_train, Y_train)
# Out:
# VotingRegressor(estimators=[('rf', RandomForestRegressor()),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, feature_types=None,
#                                           gamma=None, gpu_id=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constraints=None,
#                                           learning_rate=None, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=None,
#                                           max_leaves=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=100, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           predictor=None, random_state=None, ...)),
#                             ('svm', SVR(C=10, gamma=0.1))])

# %%
predict = vote_regressor.predict(X_test)

# %%
print(predict)
# Out:
# [ 6.44209919  5.22797166 10.46902968  4.99411312  9.39181565 15.04950118
#   8.49159774  5.05043592  3.45762001  6.14561904  2.6799994   5.65372203
#   5.47579287  2.94787663  9.41014871  4.28688017  9.97352274  6.26909731
#   6.78212248  4.87605589  4.37569349  7.3653158   4.83756545 15.56635644
#  11.51652132  4.60927644  6.47888856 12.43077701  5.76244193  5.70615731
#   1.64321052  6.21821456  6.30170805 10.30927899  6.33967911  5.01926386
#   2.89981718  6.63053254  3.59823901  6.27353011  6.0023953   6.54427614
#   5.06139051  8.57966342  4.7417184   5.04530087  3.2743404   4.46430781
#   4.95921768  4.5665242   5.51546557  1.85562099  3.10266392  6.27752663
#  10.35839265  7.31592006  4.77398801  4.77350442  6.19254216  6.39400268
#   4.68880826 10.80822654  4.11274068  9.6074645   6.38923335  4.20980707
#   6.34484655  4.05615678  6.83795583  6.47119628  3.96565731 10.40113801
#   6.8205849   3.51500486  6.73375802 11.5311259   5.14829221  4.41827559
#   5.30796272 12.34546672  4.65648861  5.45469002  6.40477254 10.79801018
#   5.1761554   5.1346658   3.17836715 16.01998618 11.19499736  6.68012232
#   2.76039333  6.45425465  4.52124794  4.60518607 11.65012824  6.75023588
#   4.70367607  5.91968931  4.80251274  5.11704763  5.00728777  4.17000245
#   1.27952712 12.2638373   4.44024657  3.67527793  5.8755106   8.51949285
#   6.08182728  6.61919344  7.09125828  1.057698    2.92961302  3.96854312
#   4.76379111  6.03386931  6.04894924  6.61512159  2.38008746  1.96985522
#   5.62505876  3.52347384  4.14614399  1.55375823  3.46426199  5.93410586
#   4.98213882  3.89731581  4.41364649  3.48910001  5.4912217   4.82180324
#   1.63747057  4.56167449  3.91725203  5.052437   10.76032153  6.39826916
#   6.4954567   4.72535227  3.61010237  6.41569955  6.08781752  2.89551252
#   3.54339067  2.76552362  5.02432312  6.53597313  6.8132177   5.99318926
#   4.35597033  6.31018599  3.81272149  3.27006028  4.66636079  2.67298469
#   6.35781663  3.78131289  3.64587534  4.01830074  4.62318209  6.17472462
#   6.88056135 10.74611624  6.47654251  1.87541578  6.10213346  5.4525225
#   3.75823787  3.96238727  5.3117717   3.04870259  5.45710424 12.17149244
#   6.37589042  2.7336446   5.92005037  6.27575239  4.94615101  5.46599899
#   5.6942974   3.31238876 10.75040015  6.09922229  8.078795    3.63659994
#   6.6190279   3.65646614  7.07526992  3.41874446  5.64036315  4.17288199
#   4.93514546  3.57952613  6.63535587  6.4091124   5.93432844  6.62119128
#   4.5094264   6.72985384  6.98653198  2.9604184   2.73582154 15.4626233
#   4.85146074  4.37991431 10.94017643  6.63494996  5.41358154  3.36377831
#   6.70336574  3.01771336  3.47087876  1.99223483  6.09687615  2.06583172
#   6.60447001  9.60838611  6.54692575  1.04995503  6.17756318  4.63361054
#   6.48229674  6.3111951   3.69852484  1.71219701  4.90009876  4.54471609
#  10.41902002 13.88205833 15.6511315   3.60870638  5.41926314]

# %%
mean_absolute_error(Y_test, predict)
# Out:
# 1.0419040558382784

# %%
rms = sqrt(mean_squared_error(Y_test, predict))

# %%
print(rms)
# Out:
# 2.1450609161736973

# %%
# R squared error
error_score = metrics.r2_score(Y_test,predict)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.5842178590803394

# %%
smape_score = smape(Y_test,predict)
print("SMAPE score:", smape_score)
# Out:
# SMAPE score: 24.56157431076839

# %%
residuals = Y_test - predict
n = len(X_test)
p = 1  # Assuming only one predictor variable
SSE = np.sum(residuals ** 2)
SE = np.sqrt(SSE / (n - p - 1))
print(SE)
# Out:
# 2.154326881189231
